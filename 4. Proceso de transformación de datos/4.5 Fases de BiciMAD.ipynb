# %%
import requests
import json
import numpy as np
import pandas as pd
import csv
import time
from math import sin, cos,asin, degrees,sqrt, atan2, radians
from datetime import datetime
import shapely.geometry

# %% [markdown]
# ## 4.5.1 Análisis de las fases

# %%
bases_fases = pd.read_csv('bases_bicimad_fases.csv', sep=";", header=0,encoding= 'unicode_escape')

# %%
bases_api = pd.read_csv('bicimad_stations.csv', sep=";", header=0)

# %%
bases_fases.sample(3)
# Out:
#     Número      Gis_X       Gis_Y Fecha de Alta        Distrito  \
# 167    163  440055,04  4472797,85    01/07/2015  02  ARGANZUELA
# 66      68  441358,92  4473802,81    23/06/2014      03  RETIRO
# 125    123  439482,59  4475800,04    23/06/2014    07  CHAMBERÍ
#
#                Barrio                       Calle Nº Finca Tipo de Reserva  \
# 167     02-02 ACACIAS     ESPERANZA, PASEO, DE LA      2 A         BiciMAD
# 66    03-05 JERÓNIMOS         ESPALTER, CALLE, DE        1         BiciMAD
# 125  07-01 GAZTAMBIDE  GUZMAN EL BUENO, CALLE, DE        2         BiciMAD
#
#      Número de Plazas  Longitud    Latitud                      Direccion
# 167                21 -3.706437  40.403635   ESPERANZA, PASEO, DE LA, 2 A
# 66                 21 -3.691165  40.412781         ESPALTER, CALLE, DE, 1
# 125                24 -3.713468  40.430639  GUZMAN EL BUENO, CALLE, DE, 2

# %%
bases_api.sample(5)
# Out:
#       id number                    name                           address  \
# 186  192    184        Marqués de Zafra           Pº Marqués de Zafra, 24
# 177  183    175   Jaime el Conquistador       Jaime I el Conquistador, 30
# 4      5      4                Malasaña       Calle Manuela Malasaña nº 5
# 46    50     46    Ribera de Curtidores  Calle Ribera de Curtidores nº 28
# 205  211    203  San Francisco de Sales                General Ampudia, 2
#
#      activate  no_available  total_bases  longitude   latitude
# 186         1             1           24  -3.665306  40.426000
# 177         1             1           21  -3.698306  40.396222
# 4           1             1           24  -3.702587  40.428552
# 46          1             1           24  -3.707126  40.405315
# 205         1             1           24  -3.714472  40.441750

# %% [markdown]
# ##### Número de estaciones de bicis del fichero 'bases_bicimad.csv'

# %%
bases_fases.count()[0]
# Out:
# 216

# %% [markdown]
# ##### Número de estaciones de bicis de la API EMT

# %%
bases_api.count()[0]
# Out:
# 214

# %% [markdown]
# #### Número de estaciones por año

# %%
bases_fases.groupby('fecha_alta_year').size()
# Out:
# fecha_alta_year
# 2014    122
# 2015     41
# 2016      1
# 2017      2
# 2018      4
# 2019     46
# dtype: int64

# %%
bases_fases_new = bases_fases[['Número','Fecha de Alta']]
bases_fases_new.columns = ['number', 'fecha_alta']
bases_fases_new.head(5)
# Out:
#   number  fecha_alta
# 0  001 a  23/06/2014
# 1  001 b  23/06/2014
# 2      2  23/06/2014
# 3      3  23/06/2014
# 4      4  23/06/2014

# %%
result = pd.merge(bases_api, bases_fases_new, how='left', on=['number'],indicator='indicator_column')

# %% [markdown]
# ##### Número de estaciones de bicis de la API EMT no encontradas en el conjunto de datos 'bases_bicimad.csv'

# %%
result[result['indicator_column'] == 'left_only']
# Out:
#       id number                    name                          address  \
# 0      1     1a        Puerta del Sol A              Puerta del Sol nº 1
# 1      2     1b        Puerta del Sol B              Puerta del Sol nº 1
# 20    21    20a       Banco de España A               Calle Alcalá nº 49
# 24    28    25a     Plaza de Celenque A           Plaza de Celenque nº 1
# 25    29    25b     Plaza de Celenque B           Plaza de Celenque nº 1
# 28    32     28                 Sevilla               Calle Alcalá nº 27
# 78    84    80a                Atocha A  Paseo de la Infanta Isabel nº 3
# 79    85    80b                Atocha B  Paseo de la Infanta Isabel nº 3
# 105  111   106a                 Colón A              Calle Serrano nº 34
# 106  112   106b                 Colón B              Calle Serrano nº 34
# 111  117   111a    Arcipreste de Hita A   Calle Arcipreste de Hita nº 12
# 112  118   111b    Arcipreste de Hita B   Calle Arcipreste de Hita nº 12
# 117  123   116a       Plaza de España A                  Plaza de España
# 118  124   116b       Plaza de España B                  Plaza de España
# 180  186    178  Junta Municipal Retiro         Plaza de Daoíz y Velarde
#
#      activate  no_available  total_bases  longitude   latitude fecha_alta  \
# 0           1             1           30  -3.701781  40.417153        NaN
# 1           1             1           30  -3.702421  40.417001        NaN
# 20          1             1           30  -3.695461  40.419234        NaN
# 24          1             1           24  -3.706481  40.417311        NaN
# 25          1             1           24  -3.706384  40.417278        NaN
# 28          1             1           24  -3.699260  40.418166        NaN
# 78          1             1           24  -3.690225  40.407568        NaN
# 79          1             1           27  -3.690123  40.407490        NaN
# 105         1             1           18  -3.687723  40.425100        NaN
# 106         1             1           18  -3.687745  40.424963        NaN
# 111         1             1           24  -3.717543  40.433732        NaN
# 112         1             1           24  -3.717511  40.433704        NaN
# 117         1             1           24  -3.711603  40.424020        NaN
# 118         1             1           24  -3.711703  40.424120        NaN
# 180         1             1           24  -3.678834  40.402920        NaN
#
#     indicator_column
# 0          left_only
# 1          left_only
# 20         left_only
# 24         left_only
# 25         left_only
# 28         left_only
# 78         left_only
# 79         left_only
# 105        left_only
# 106        left_only
# 111        left_only
# 112        left_only
# 117        left_only
# 118        left_only
# 180        left_only

# %%
result[result['indicator_column'] == 'left_only'] .count()[0]
# Out:
# 15

# %% [markdown]
# ##### Lectura del fichero con la asignación manual de claves

# %%
bases_fases = pd.read_csv('bases_bicimad_update.csv', sep=";", header=0)

# %%
bases_fases['Fecha de Alta'] = pd.to_datetime(bases_fases['Fecha de Alta'],format="%d/%m/%Y")

# %%
bases_fases['fecha_alta_year'] = bases_fases['Fecha de Alta'].dt.year

# %%
def set_etapa(year):
    if(year == 2014):
        return "1"
    elif (year == 2015):
        return "2"
    elif (year == 2019):
        return "3"
    else:
        return "-1"

bases_fases['etapa'] = bases_fases.apply(lambda x: set_etapa(x.fecha_alta_year), axis=1)

# %%
bases_fases_new = bases_fases[['Número','Fecha de Alta','Calle','Distrito','Barrio','etapa']]
bases_fases_new.columns = ['number', 'fecha_alta','direccion','distrito','barrio','etapa']

# %%
estaciones_bici_etapa = pd.merge(bases_api, bases_fases_new, how='left', on=['number'],indicator='indicator_column')

# %% [markdown]
# ##### Estaciones de bicicleta sin clasificar

# %%
estaciones_bici_etapa[(estaciones_bici_etapa['indicator_column'] == 'left_only') | (estaciones_bici_etapa['etapa'] == "-1")]
# Out:
#       id number                    name                      address  \
# 20    21    20a       Banco de España A           Calle Alcalá nº 49
# 28    32     28                 Sevilla           Calle Alcalá nº 27
# 105  111   106a                 Colón A          Calle Serrano nº 34
# 106  112   106b                 Colón B          Calle Serrano nº 34
# 132  157    130      Santa Engracia 127  Calle Santa Engracia nº 127
# 168  174    166              Segovia 26            Calle Segovia, 26
# 169  175    167              Segovia 45            Calle Segovia, 45
# 180  186    178  Junta Municipal Retiro     Plaza de Daoíz y Velarde
#
#      activate  no_available  total_bases  longitude   latitude fecha_alta  \
# 20          1             1           30  -3.695461  40.419234 2018-07-10
# 28          1             1           24  -3.699260  40.418166        NaT
# 105         1             1           18  -3.687723  40.425100        NaT
# 106         1             1           18  -3.687745  40.424963        NaT
# 132         1             1           20  -3.701632  40.441386 2017-06-21
# 168         1             1           24  -3.713583  40.413833 2016-06-23
# 169         1             1           24  -3.717487  40.413736 2017-05-22
# 180         1             1           24  -3.678834  40.402920        NaT
#
#                      direccion        distrito            barrio etapa  \
# 20           ALCALA, CALLE, DE      01  CENTRO    01-04 JUSTICIA    -1
# 28                         NaN             NaN               NaN   NaN
# 105                        NaN             NaN               NaN   NaN
# 106                        NaN             NaN               NaN   NaN
# 132  SANTA ENGRACIA, CALLE, DE    07  CHAMBERÍ  07-05 RÍOS ROSAS    -1
# 168         SEGOVIA, CALLE, DE      01  CENTRO     01-01 PALACIO    -1
# 169         SEGOVIA, CALLE, DE  02  ARGANZUELA    02-01 IMPERIAL    -1
# 180                        NaN             NaN               NaN   NaN
#
#     indicator_column
# 20              both
# 28         left_only
# 105        left_only
# 106        left_only
# 132             both
# 168             both
# 169             both
# 180        left_only

# %%
estaciones_bici_etapa.to_csv('estaciones_etapa_emt.csv', sep=';', encoding='utf-8',index=False)

# %%
estaciones_bici_etapa.head(5)
# Out:
#    id number                name                        address  activate  \
# 0   1     1a    Puerta del Sol A            Puerta del Sol nº 1         1
# 1   2     1b    Puerta del Sol B            Puerta del Sol nº 1         1
# 2   3      2         Miguel Moya         Calle Miguel Moya nº 1         1
# 3   4      3  Plaza Conde Suchil  Plaza del Conde Suchil nº 2-4         1
# 4   5      4            Malasaña    Calle Manuela Malasaña nº 5         1
#
#    no_available  total_bases  longitude   latitude  fecha_alta  \
# 0             1           30  -3.701781  40.417153  2014-06-23
# 1             1           30  -3.702421  40.417001  2014-06-23
# 2             1           24  -3.705842  40.420589  2014-06-23
# 3             1           18  -3.706917  40.430294  2014-06-23
# 4             1           24  -3.702587  40.428552  2014-06-23
#
#                                direccion      distrito             barrio  \
# 0           PUERTA DEL SOL, PLAZA, DE LA    01  CENTRO          01-06 SOL
# 1                      ALCALA, CALLE, DE    01  CENTRO          01-06 SOL
# 2                 MIGUEL MOYA, CALLE, DE    01  CENTRO  01-05 UNIVERSIDAD
# 3  CONDE DEL VALLE DE SUCHIL, PLAZA, DEL  07  CHAMBERÍ     07-02 ARAPILES
# 4            MANUELA MALASAÑA, CALLE, DE    01  CENTRO  01-05 UNIVERSIDAD
#
#    etapa indicator_column
# 0    1.0             both
# 1    1.0             both
# 2    1.0             both
# 3    1.0             both
# 4    1.0             both

# %% [markdown]
# ##### Análisis con los movimientos

# %%
estaciones_bicimad_totales = pd.read_csv('estaciones_bicimad_totales_agregado.csv', sep=";", header=0)

# %%
movimientos = pd.read_csv('movimientos_general.csv', sep=";", header=0)

# %%
lines_movimientos = [key for key, data in movimientos.groupby('id_line')]

# %%
lines_totales = [key for key, data in estaciones_bicimad_totales.groupby('id_line')]

# %%
lines_not = list(set(lines_totales)-set(lines_movimientos))

# %% [markdown]
# ##### Líneas no encontradas en los movimientos

# %%
lines_not
# Out:
# [1, 37, 12, 148, 149, 152, 56, 27]

# %% [markdown]
# ##### Extracción de las rutas de bicicleta en función de las líneas donde no se encontraron movimientos

# %%
rutas_not = estaciones_bicimad_totales[estaciones_bicimad_totales['id_line'].isin(lines_not)][['id_line','id_header_origen','name_header_origen','id_bicimad_origen','id_header_destino','name_header_destino','id_bicimad_destino']]

# %%
estaciones_bici_etapa = pd.read_csv('estaciones_etapa_emt.csv', sep=";", header=0)
estaciones_bici_etapa_1 = estaciones_bici_etapa[['id','etapa','fecha_alta']]
estaciones_bici_etapa_1['id_bicimad_origen'] = estaciones_bici_etapa_1['id']
estaciones_bici_etapa_1.drop('id', axis=1, inplace=True)
aux = pd.merge(rutas_not, estaciones_bici_etapa_1, how='left', on=['id_bicimad_origen'])
aux.rename(columns={'etapa': 'etapa_origen', 'fecha_alta': 'fecha_alta_origen'}, inplace=True)
estaciones_bici_etapa_1['id_bicimad_destino'] = estaciones_bici_etapa_1['id_bicimad_origen']
estaciones_bici_etapa_1.drop('id_bicimad_origen', axis=1, inplace=True)
aux = pd.merge(aux, estaciones_bici_etapa_1, how='left', on=['id_bicimad_destino'])
aux.rename(columns={'etapa': 'etapa_destino', 'fecha_alta': 'fecha_alta_destino'}, inplace=True)
aux
# Out:
# C:\Users\Arturo\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Arturo\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\Arturo\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#     id_line  id_header_origen name_header_origen  id_bicimad_origen  \
# 0         1              4514         Cristo Rey                160
# 1        12              4541         Cristo Rey                160
# 2        12              4541         Cristo Rey                211
# 3        27                86        Embajadores                 51
# 4        27                86        Embajadores                 51
# 5        27                86        Embajadores                 52
# 6        27                86        Embajadores                 52
# 7        27                86        Embajadores                 53
# 8        27                86        Embajadores                 53
# 9        37              1381     Cuatro Caminos                149
# 10       37              1381     Cuatro Caminos                212
# 11       56              2224      Diego de León                166
# 12       56              2224      Diego de León                170
# 13       56              2224      Diego de León                199
# 14       56              2224      Diego de León                202
# 15      148              5571             Callao                  3
# 16      148              5571             Callao                 25
# 17      148              5571             Callao                 26
# 18      149              4229           Tribunal                  5
# 19      149              4229           Tribunal                  5
# 20      149              4229           Tribunal                  6
# 21      149              4229           Tribunal                  6
# 22      149              4229           Tribunal                  8
# 23      149              4229           Tribunal                  8
# 24      149              4229           Tribunal                 58
# 25      149              4229           Tribunal                 58
# 26      152              2153          Felipe II                 96
# 27      152              2153          Felipe II                102
# 28      152              2153          Felipe II                103
# 29      152              2153          Felipe II                104
# 30      152              2153          Felipe II                105
#
#     id_header_destino     name_header_destino  id_bicimad_destino  \
# 0                 273             Prosperidad                 204
# 1                 779        Marqués de Zafra                 193
# 2                 779        Marqués de Zafra                 193
# 3                5602          Plaza Castilla                 216
# 4                5602          Plaza Castilla                 217
# 5                5602          Plaza Castilla                 216
# 6                5602          Plaza Castilla                 217
# 7                5602          Plaza Castilla                 216
# 8                5602          Plaza Castilla                 217
# 9                1000      Puente de Vallecas                 187
# 10               1000      Puente de Vallecas                 187
# 11               1000      Puente de Vallecas                 187
# 12               1000      Puente de Vallecas                 187
# 13               1000      Puente de Vallecas                 187
# 14               1000      Puente de Vallecas                 187
# 15               3662      Puente de Vallecas                 187
# 16               3662      Puente de Vallecas                 187
# 17               3662      Puente de Vallecas                 187
# 18               1531          Plaza Castilla                 216
# 19               1531          Plaza Castilla                 217
# 20               1531          Plaza Castilla                 216
# 21               1531          Plaza Castilla                 217
# 22               1531          Plaza Castilla                 216
# 23               1531          Plaza Castilla                 217
# 24               1531          Plaza Castilla                 216
# 25               1531          Plaza Castilla                 217
# 26               2921  Méndez Álvaro-Terminal                 188
# 27               2921  Méndez Álvaro-Terminal                 188
# 28               2921  Méndez Álvaro-Terminal                 188
# 29               2921  Méndez Álvaro-Terminal                 188
# 30               2921  Méndez Álvaro-Terminal                 188
#
#     etapa_origen fecha_alta_origen  etapa_destino fecha_alta_destino
# 0            2.0        2015-07-01            3.0         2019-10-21
# 1            2.0        2015-07-01            3.0         2019-08-01
# 2            3.0        2019-05-27            3.0         2019-08-01
# 3            1.0        2014-06-23            3.0         2019-09-30
# 4            1.0        2014-06-23            3.0         2019-09-30
# 5            1.0        2014-06-23            3.0         2019-09-30
# 6            1.0        2014-06-23            3.0         2019-09-30
# 7            1.0        2014-06-23            3.0         2019-09-30
# 8            1.0        2014-06-23            3.0         2019-09-30
# 9            2.0        2015-07-01            3.0         2019-09-30
# 10           3.0        2019-08-01            3.0         2019-09-30
# 11           2.0        2015-07-01            3.0         2019-09-30
# 12           2.0        2015-06-20            3.0         2019-09-30
# 13           3.0        2019-08-23            3.0         2019-09-30
# 14           3.0        2019-09-30            3.0         2019-09-30
# 15           1.0        2014-06-23            3.0         2019-09-30
# 16           1.0        2014-06-23            3.0         2019-09-30
# 17           1.0        2014-06-23            3.0         2019-09-30
# 18           1.0        2014-06-23            3.0         2019-09-30
# 19           1.0        2014-06-23            3.0         2019-09-30
# 20           1.0        2014-06-23            3.0         2019-09-30
# 21           1.0        2014-06-23            3.0         2019-09-30
# 22           1.0        2014-06-23            3.0         2019-09-30
# 23           1.0        2014-06-23            3.0         2019-09-30
# 24           1.0        2014-06-23            3.0         2019-09-30
# 25           1.0        2014-06-23            3.0         2019-09-30
# 26           1.0        2014-06-23            3.0         2019-09-11
# 27           1.0        2014-06-23            3.0         2019-09-11
# 28           1.0        2014-06-23            3.0         2019-09-11
# 29           1.0        2014-06-23            3.0         2019-09-11
# 30           1.0        2014-06-23            3.0         2019-09-11

# %% [markdown]
# ##### Número de rutas sin movimientos

# %%
rutas_not.count()[0]
# Out:
# 31

# %% [markdown]
# ##### Número de rutas con alguna cabecera de origen inaugurada en la tercera fase

# %%
aux[aux['etapa_origen'] == 3].count()[0]
# Out:
# 4

# %% [markdown]
# ##### Número de rutas con alguna cabecera de destino inaugurada en la tercera fase

# %%
aux[aux['etapa_destino'] == 3].count()[0]
# Out:
# 31

# %% [markdown]
# ##### Fecha más antigua de inauguración de alguna cabecera de destino

# %%
aux[aux['etapa_destino'] == 3][['fecha_alta_destino']].min()[0]
# Out:
# '2019-08-01'

# %% [markdown]
# ##### Fecha más reciente de inauguración de alguna cabecera de destino

# %%
aux[aux['etapa_destino'] == 3][['fecha_alta_destino']].max()[0]
# Out:
# '2019-10-21'

# %% [markdown]
# ## 4.5.2 Asignación de estaciones aledañas

# %% [markdown]
# #### Seleccionamos aquellas estaciones de origen distintas

# %%
list_origen = aux[aux['etapa_origen'] == 3].drop_duplicates('id_bicimad_origen')[['id_bicimad_origen']].sort_values('id_bicimad_origen')['id_bicimad_origen'].to_list()
origen_fase_iii = bases_api[bases_api['id'].isin(list_origen)][['id','latitude','longitude']]
origen_fase_iii
# Out:
#       id   latitude  longitude
# 193  199  40.434639  -3.674000
# 196  202  40.437250  -3.677222
# 205  211  40.441750  -3.714472
# 206  212  40.447667  -3.704167

# %% [markdown]
# #### Seleccionamos aquellas estaciones de destino distintas

# %%
list_destino = aux[aux['etapa_destino'] == 3].drop_duplicates('id_bicimad_destino')[['id_bicimad_destino']].sort_values('id_bicimad_destino')['id_bicimad_destino'].to_list()
destino_fase_iii = bases_api[bases_api['id'].isin(list_destino)][['id','latitude','longitude']]
destino_fase_iii
# Out:
#       id   latitude  longitude
# 181  187  40.397972  -3.669250
# 182  188  40.394139  -3.675889
# 187  193  40.425083  -3.661528
# 198  204  40.444139  -3.675139
# 210  216  40.466361  -3.688639
# 211  217  40.465917  -3.688472

# %% [markdown]
# #### buscamos aquellas estaciones cercanas que no sean de fase III

# %%
def calcular_distancia(lat1, lon1, lat2, lon2):
    R = 6373.0
    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * (sin(dlon/2))**2
    c = 2 * atan2( sqrt(a), sqrt(1-a) )
    return R * c * 1000

# %%
def calcular_distancia_con_coordinates(row_orig,radio,df):
    res = []
    for index, row in df.iterrows():
        distancia = calcular_distancia(row_orig.latitude,row_orig.longitude,row.latitude,row.longitude) 
        if row.id != row_orig.id and row.etapa != 3 and distancia <= radio:
            row['estacion_ori_id'] = row_orig.id
            res.append(row)
    return pd.DataFrame(res)

# %%
def buscar_estaciones(df,radio):
    aux = []
    for index, row in df.iterrows():
        res = calcular_distancia_con_coordinates(row,radio,estaciones_bici_etapa)
        if(not res.empty): aux.append(res)
    if not aux: return None
    else: return pd.concat(aux)

# %% [markdown]
# ##### Estaciones que sustituyen a las anteriores en cabecera de origen de bicimad

# %%
aledanias_origen = buscar_estaciones(origen_fase_iii,300)[["id","name","fecha_alta","etapa","estacion_ori_id"]]
aledanias_origen
# Out:
#       id                            name  fecha_alta  etapa  estacion_ori_id
# 146  170                   Juan Bravo 50  2015-06-20    2.0            199.0
# 134  149  Glorieta de los Cuatro Caminos  2015-07-01    2.0            212.0

# %% [markdown]
# ##### Estaciones que sustituyen a las anteriores en cabecera de destino de bicimad

# %%
aledanias_destino = buscar_estaciones(destino_fase_iii,300)
aledanias_destino

# %% [markdown]
# ##### Comprobar si las estaciones aledañas ya han sido agregadas

# %%
def comprobar_estaciones_aledanias():
    aux = []
    for index, row in aledanias_origen.iterrows():
        id_line_original = estaciones_bicimad_totales[estaciones_bicimad_totales['id_bicimad_origen'] == row.estacion_ori_id][['id_line']].values[0][0]
        if id_line_original != estaciones_bicimad_totales[estaciones_bicimad_totales['id_bicimad_origen'] == row.id][['id_line']].values[0][0]:
            aux.append(row)
    return aux

# %%
print(comprobar_estaciones_aledanias())
# Out:
# []
